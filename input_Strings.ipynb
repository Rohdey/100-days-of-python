# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohdey/100-days-of-python/blob/main/input_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# taking input

# %%
a = input("enter your input")
b = input("enter your input")
print(int(a)/int(b))
# Out:
# enter your input8
# enter your input9
# 0.8888888888888888

# %%
# Strings

# %%
a = "karan"
b = "lovish"
print(a+b)
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
# print(a[5]) throws an error
x = 'helloo "he said it"'
print(x)
# 0r
x = "helloo \"he said it\""
print(x)

y = '''ValueError  Traceback (most recent call last)
<ipython-input-5-b2f4055a7520> in <cell line: 3>()
      1 a = input("enter your input")
      2 b = input("enter your input")
----> 3 print(int(a)/int(b))

ValueError: invalid literal for int() with base 10: 'harry'
'''

print(y)
for character in y:
    print(character)
# Out:
# karanlovish
# k
# a
# r
# a
# n
# helloo "he said it"
# helloo "he said it"
# ValueError  Traceback (most recent call last)
# <ipython-input-5-b2f4055a7520> in <cell line: 3>()
#       1 a = input("enter your input")
#       2 b = input("enter your input")
# ----> 3 print(int(a)/int(b))
#
# ValueError: invalid literal for int() with base 10: 'harry'
#
# V
# a
# l
# u
# e
# E
# r
# r
# o
# r
#
#
# T
# r
# a
# c
# e
# b
# a
# c
# k
#
# (
# m
# o
# s
# t
#
# r
# e
# c
# e
# n
# t
#
# c
# a
# l
# l
#
# l
# a
# s
# t
# )
#
#
# <
# i
# p
# y
# t
# h
# o
# n
# -
# i
# n
# p
# u
# t
# -
# 5
# -
# b
# 2
# f
# 4
# 0
# 5
# 5
# a
# 7
# 5
# 2
# 0
# >
#
# i
# n
#
# <
# c
# e
# l
# l
#
# l
# i
# n
# e
# :
#
# 3
# >
# (
# )
#
#
#
#
#
#
#
#
# 1
#
# a
#
# =
#
# i
# n
# p
# u
# t
# (
# "
# e
# n
# t
# e
# r
#
# y
# o
# u
# r
#
# i
# n
# p
# u
# t
# "
# )
#
#
#
#
#
#
#
#
# 2
#
# b
#
# =
#
# i
# n
# p
# u
# t
# (
# "
# e
# n
# t
# e
# r
#
# y
# o
# u
# r
#
# i
# n
# p
# u
# t
# "
# )
#
#
# -
# -
# -
# -
# ...
